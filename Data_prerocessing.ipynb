# %%
#imports
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from ast import literal_eval

# %%
df_credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
df_credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
df_movies = pd.read_csv('tmdb_5000_movies.csv')

# %%
df_movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage  movie_id  \
# 0                   http://www.avatarmovie.com/     19995
# 1  http://disney.go.com/disneypictures/pirates/       285
# 2   http://www.sonypictures.com/movies/spectre/    206647
# 3            http://www.thedarkknightrises.com/     49026
# 4          http://movies.disney.com/john-carter     49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# df_movies.release_date.value_counts(dropna=False).sort_index().plot(kind='barh',figsize=(15,16))
# plt.show()

# %%
movies = df_movies.merge(df_credits,on='movie_id')

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'movie_id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline',
#        'title_x', 'vote_average', 'vote_count', 'title_y', 'cast', 'crew'],
#       dtype='object')

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'movie_id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline',
#        'title_x', 'vote_average', 'vote_count', 'title_y', 'cast', 'crew'],
#       dtype='object')

# %%
movies = movies.drop(columns=['title_x', 'tagline', 'status', 'homepage', 
                                        'keywords','crew','vote_count',
                                       'tagline', 'spoken_languages', 'runtime',
                                       'popularity', 'production_companies', 'budget',
                                       'production_countries', 'revenue',
                                        'title_y', 'original_language'])

# %%
movies.head()
# Out:
#                                               genres  movie_id  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...     19995
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...       285
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...    206647
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...     49026
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...     49529
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview release_date  \
# 0  In the 22nd century, a paraplegic Marine is di...   2009-12-10
# 1  Captain Barbossa, long believed to be dead, ha...   2007-05-19
# 2  A cryptic message from Bond’s past sends him o...   2015-10-26
# ...

# %%
features = ['cast', 'genres']
for feature in features:
    movies[feature] = movies[feature].apply(literal_eval)

# %%
features
# Out:
# ['cast', 'genres']

# %%
def get_list(meta_data):
    if isinstance(meta_data, list):
        names = [col['name'] for col in meta_data]
        #Check if more than 3 elements exist. If yes, return only first three. If no, return entire list.
        if len(names) > 3:
            names = names[:3]
        return names

    #Return empty list in case of missing/malformed data
    return []

features = ['cast','genres']
for feature in features:
    movies[feature] = movies[feature].apply(get_list)

# %%
movies.head()
# Out:
#                                  genres  movie_id  \
# 0          [Action, Adventure, Fantasy]     19995
# 1          [Adventure, Fantasy, Action]       285
# 2            [Action, Adventure, Crime]    206647
# 3                [Action, Crime, Drama]     49026
# 4  [Action, Adventure, Science Fiction]     49529
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview release_date  \
# 0  In the 22nd century, a paraplegic Marine is di...   2009-12-10
# 1  Captain Barbossa, long believed to be dead, ha...   2007-05-19
# 2  A cryptic message from Bond’s past sends him o...   2015-10-26
# 3  Following the death of District Attorney Harve...   2012-07-16
# ...

# %%
movies.isna().sum()
# Out:
# genres            0
# movie_id          0
# original_title    0
# overview          3
# cast              0
# dtype: int64

# %%
movies.isnull().sum()
# Out:
# genres            0
# movie_id          0
# original_title    0
# overview          3
# cast              0
# dtype: int64

# %%
movies['overview'] = movies['overview'].replace(np.nan, 'unkown')

# %%
movies.isna().sum()
# Out:
# genres            0
# movie_id          0
# original_title    0
# overview          0
# cast              0
# dtype: int64

# %%
movies.columns
# Out:
# Index(['genres', 'movie_id', 'original_title', 'overview', 'release_date',
#        'vote_average', 'cast'],
#       dtype='object')

# %%
hindi = pd.read_csv('bollywood_full_1950-2019.csv')

# %%
hindi.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
hindi = hindi.drop(columns=['title_x', 'tagline', 'poster_path', 
                                        'wiki_link','title_y','is_adult', 'year_of_release',
                                       'tagline',  'runtime',
                                       'imdb_votes', 'story',
                                       'wins_nominations'])

hindi.rename(columns = {'actors':'cast', 'summary':'overview', 'imdb_id':'movie_id', 'imdb_rating':'vote_average'}, inplace = True)

hindi['genres'] = hindi['genres'].str.split('|')

hindi['cast'] = hindi['cast'].str.split('|')

# %%
hindi.columns
# Out:
# Index(['movie_id', 'original_title', 'genres', 'vote_average', 'overview',
#        'cast', 'release_date'],
#       dtype='object')

# %%
movies.columns
# Out:
# Index(['genres', 'movie_id', 'original_title', 'overview', 'release_date',
#        'vote_average', 'cast'],
#       dtype='object')

# %%
def clean_data(actors):
    if isinstance(actors, list):
        return actors[:3]

features = ['cast']
for feature in features:
    hindi[feature] = hindi[feature].apply(clean_data)

hindi.head()
# Out:
#     movie_id                 original_title                genres  \
# 0  tt8291224       Uri: The Surgical Strike  [Action, Drama, War]
# 1  tt9472208                  Battalion 609                 [War]
# 2  tt6986710  The Accidental Prime Minister    [Biography, Drama]
# 3  tt8108208                Why Cheat India        [Crime, Drama]
# 4  tt6028796                Evening Shadows               [Drama]
#
#    vote_average                                           overview  \
# 0           8.4  Indian army special forces execute a covert op...
# 1           4.1  The story of Battalion 609 revolves around a c...
# 2           6.1  Explores Manmohan Singh's tenure as the Prime ...
# 3           6.0  The movie focuses on existing malpractices in ...
# 4           7.3  Under the 'Evening Shadows'  truth often plays...
#
#                                                 cast             release_date
# 0         [Vicky Kaushal, Paresh Rawal, Mohit Raina]    11 January 2019 (USA)
# ...

# %%
hindi.isnull().sum()
# Out:
# movie_id             0
# original_title       0
# genres               0
# vote_average        13
# overview             1
# cast                10
# release_date      1281
# dtype: int64

# %%
hindi['overview'] = hindi['overview'].replace(np.nan, 'unkown')
hindi['cast'] = hindi['cast'].replace(np.nan, 'unkown')
hindi['vote_average'] = hindi['vote_average'].replace(np.nan, 'unkown')

# %%
movies.columns
# Out:
# Index(['genres', 'movie_id', 'original_title', 'overview', 'release_date',
#        'vote_average', 'cast'],
#       dtype='object')

# %%
hindi.columns
# Out:
# Index(['movie_id', 'original_title', 'genres', 'vote_average', 'overview',
#        'cast', 'release_date'],
#       dtype='object')

# %%
#### Combining the bollywood and hollywoord movies

total_movies = movies.append(hindi, ignore_index=True, sort=True)

# %%
total_movies.head()
# Out:
#                                                cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]
# 3      [Christian Bale, Michael Caine, Gary Oldman]
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]
#
#                                  genres movie_id  \
# 0          [Action, Adventure, Fantasy]    19995
# 1          [Adventure, Fantasy, Action]      285
# 2            [Action, Adventure, Crime]   206647
# 3                [Action, Crime, Drama]    49026
# 4  [Action, Adventure, Science Fiction]    49529
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
total_movies.tail()
# Out:
#                                             cast           genres   movie_id  \
# 9128  [Ashok Kumar, Nalini Jaywant, Kuldip Kaur]          [Drama]  tt0268614
# 9129        [Ashok Kumar, Nalini Jaywant, Nawab]          [Drama]  tt0244182
# 9130            [Raj Kapoor, Rehana, Om Prakash]  [Drama, Family]  tt0269826
# 9131     [Sohrab Modi, Naseem Banu, Pushpa Hans]          [Drama]  tt0243555
# 9132                                      unkown          [Drama]  tt0213081
#
#      original_title                                           overview  \
# 9128        Samadhi  The story is based on the true incident at INA...
# 9129        Sangram  After the death of his wife  a policeman fails...
# 9130         Sargam                                       Add a Plot »
# 9131   Sheesh Mahal  Thakur Jaspal Singh lives in the prestigious a...
# 9132   Meena Bazaar                                       Add a Plot »
#
#                 release_date vote_average
# ...

# %%
total_movies.to_csv('movie_data.csv', index = False)

# %%
data1 = pd.read_csv('movie_data.csv')

# %%
data1.tail()
# Out:
#                                                   cast               genres  \
# 9128  ['Ashok Kumar', 'Nalini Jaywant', 'Kuldip Kaur']            ['Drama']
# 9129        ['Ashok Kumar', 'Nalini Jaywant', 'Nawab']            ['Drama']
# 9130            ['Raj Kapoor', 'Rehana', 'Om Prakash']  ['Drama', 'Family']
# 9131     ['Sohrab Modi', 'Naseem Banu', 'Pushpa Hans']            ['Drama']
# 9132                                            unkown            ['Drama']
#
#        movie_id original_title  \
# 9128  tt0268614        Samadhi
# 9129  tt0244182        Sangram
# 9130  tt0269826         Sargam
# 9131  tt0243555   Sheesh Mahal
# 9132  tt0213081   Meena Bazaar
#
#                                                overview  \
# 9128  The story is based on the true incident at INA...
# 9129  After the death of his wife  a policeman fails...
# 9130                                       Add a Plot »
# 9131  Thakur Jaspal Singh lives in the prestigious a...
# ...

# %%
movie_name = data1['original_title'].to_list()
